# %% [markdown]
# ## Setup

# %%
import pandas as pd
import spacy
import re

import warnings

pd.set_option('display.max_columns', None)

nlp = spacy.load("en_core_web_sm")

warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
def preprocess_text_spacy(text):
    if pd.isna(text):
        return ""
    # 1. Minúsculas
    text = text.lower()
    # 2. Remoção de pontuação e números
    text = re.sub(r"[^a-zA-Z\s]", "", text)
    # 3. Processamento com spaCy (Tokenização, remoção de stopwords e lematização)
    doc = nlp(text)
    clean_tokens = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]
    return " ".join(clean_tokens)

# %%
def categorize_rating(rating):
    if rating < 4:
        return 'Negativo'
    elif 4 <= rating <= 7:
        return 'Neutro'
    else:
        return 'Positivo'

# %% [markdown]
# ## 1. Entendimento e Processamento dos dados

# %% [markdown]
# * Visão geral dos dados
# * Identificação e exclusão de dados duplicados
# * Identificação de dados não validos de 'Overall_Rating' e exclusão destes
# * Conversão do tipo de dado: Overall_Rating -> numeric; Review Date e Date Flown -> datetime
# * Padronização do nome das features

# %%
df = pd.read_csv('../data/raw/Travel_Chalenge.csv', sep=';')
df.head(2)
# Out:
#      Airline Name Overall_Rating                    Review_Title  \
# 0  Air Seychelles              8  Air Seychelles customer review
# 1         CityJet              1         CityJet customer review
#
#        Review Date                                             Review  \
# 0  10th April 2011  LHR-SEZ-LHR. It's true that there aren't perso...
# 1  10th April 2011  London City to Antwerp was delayed 3 hours 40 ...
#
#   Aircraft Type Of Traveller      Seat Type Route Date Flown  Seat Comfort  \
# 0      NaN               NaN  Economy Class   NaN        NaN           NaN
# 1      NaN               NaN  Economy Class   NaN        NaN           NaN
#
#    Cabin Staff Service  Food & Beverages  Ground Service  \
# 0                  NaN               NaN             NaN
# 1                  NaN               NaN             NaN
#
#    Inflight Entertainment  Wifi & Connectivity
# 0                     NaN                  NaN
# 1                     NaN                  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17702 entries, 0 to 17701
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Airline Name            17702 non-null  object
#  1   Overall_Rating          17702 non-null  object
#  2   Review_Title            17702 non-null  object
#  3   Review Date             17702 non-null  object
#  4   Review                  17702 non-null  object
#  5   Aircraft                5665 non-null   object
#  6   Type Of Traveller       15953 non-null  object
#  7   Seat Type               17461 non-null  object
#  8   Route                   15876 non-null  object
#  9   Date Flown              15944 non-null  object
#  10  Seat Comfort            15456 non-null  float64
#  11  Cabin Staff Service     15366 non-null  float64
#  12  Food & Beverages        11924 non-null  float64
#  13  Ground Service          15056 non-null  float64
#  14  Inflight Entertainment  9231 non-null   float64
#  15  Wifi & Connectivity     5243 non-null   float64
# dtypes: float64(6), object(10)
# memory usage: 2.2+ MB

# %%
((df.isnull().sum() / len(df)) * 100).round(2)
# Out:
# Airline Name               0.00
# Overall_Rating             0.00
# Review_Title               0.00
# Review Date                0.00
# Review                     0.00
# Aircraft                  68.00
# Type Of Traveller          9.88
# Seat Type                  1.36
# Route                     10.32
# Date Flown                 9.93
# Seat Comfort              12.69
# Cabin Staff Service       13.20
# Food & Beverages          32.64
# Ground Service            14.95
# Inflight Entertainment    47.85
# Wifi & Connectivity       70.38
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(29)

# %%
df[df.duplicated()].head()
# Out:
#        Airline Name Overall_Rating                   Review_Title  \
# 514   Edelweiss Air              n  Edelweiss Air customer review
# 516          Kulula              n         Kulula customer review
# 1065         Luxair              n         Luxair customer review
# 1352         Luxair              4         Luxair customer review
# 1549         Kulula              n         Kulula customer review
#
#               Review Date                                             Review  \
# 514   10th September 2003  I flew Edelweiss to Antalya a couple of days a...
# 516   10th September 2006  Great airline with its excellent prices and ca...
# 1065    11th October 2004  Economy from Manchester to Luxembourg. Very ni...
# 1352       12th July 2007  LUX-CDG on a ERJ and back on new Q400. As alwa...
# 1549        12th May 2007  Cape Town to Johannesburg. Very cheap ticket w...
#
#      Aircraft Type Of Traveller Seat Type Route Date Flown  Seat Comfort  \
# 514       NaN               NaN       NaN   NaN        NaN           NaN
# 516       NaN               NaN       NaN   NaN        NaN           NaN
# 1065      NaN               NaN       NaN   NaN        NaN           NaN
# 1352      NaN               NaN       NaN   NaN        NaN           NaN
# 1549      NaN               NaN       NaN   NaN        NaN           NaN
#
#       Cabin Staff Service  Food & Beverages  Ground Service  \
# 514                   NaN               NaN             NaN
# 516                   NaN               NaN             NaN
# 1065                  NaN               NaN             NaN
# 1352                  NaN               NaN             NaN
# 1549                  NaN               NaN             NaN
#
#       Inflight Entertainment  Wifi & Connectivity
# 514                      NaN                  NaN
# 516                      NaN                  NaN
# 1065                     NaN                  NaN
# 1352                     NaN                  NaN
# 1549                     NaN                  NaN

# %%
df['Review'].iloc[514]
# Out:
# 'I flew Edelweiss to Antalya a couple of days ago and back on its only A-330. The service was excellent and cabin crew very friendly. More movies would have been great. The plane was flown by CEO Kistler on the leg to Antalya. Unfortunately check-in at Antalya took relatively long since only 3 counters were open for an A-330-flight.'

# %%
df[df.Review == 'I flew Edelweiss to Antalya a couple of days ago and back on its only A-330. The service was excellent and cabin crew very friendly. More movies would have been great. The plane was flown by CEO Kistler on the leg to Antalya. Unfortunately check-in at Antalya took relatively long since only 3 counters were open for an A-330-flight.']
# Out:
#       Airline Name Overall_Rating                   Review_Title  \
# 513  Edelweiss Air              n  Edelweiss Air customer review
# 514  Edelweiss Air              n  Edelweiss Air customer review
#
#              Review Date                                             Review  \
# 513  10th September 2003  I flew Edelweiss to Antalya a couple of days a...
# 514  10th September 2003  I flew Edelweiss to Antalya a couple of days a...
#
#     Aircraft Type Of Traveller Seat Type Route Date Flown  Seat Comfort  \
# 513      NaN               NaN       NaN   NaN        NaN           NaN
# 514      NaN               NaN       NaN   NaN        NaN           NaN
#
#      Cabin Staff Service  Food & Beverages  Ground Service  \
# 513                  NaN               NaN             NaN
# 514                  NaN               NaN             NaN
#
#      Inflight Entertainment  Wifi & Connectivity
# 513                     NaN                  NaN
# 514                     NaN                  NaN

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (17673, 16)

# %%
df.sample(3)
# Out:
#                  Airline Name Overall_Rating  \
# 1263  China Southern Airlines              1
# 5429       Caribbean Airlines              8
# 6580              Germanwings              n
#
#                             Review_Title         Review Date  \
# 1263         "a very pleasant long trip"  12th December 2022
# 5429  Caribbean Airlines customer review   19th January 2015
# 6580         Germanwings customer review  20th December 2012
#
#                                                  Review Aircraft  \
# 1263    I would like to thank China Southern Airline...      NaN
# 5429  Flew from Barbados to Kingston last week. All ...      NaN
# 6580  Flew to Cologne from LHR - return flight had t...      NaN
#
#      Type Of Traveller      Seat Type                 Route     Date Flown  \
# 1263      Solo Leisure  Economy Class  Guangzhou to Toronto  December 2022
# 5429               NaN  Economy Class                   NaN            NaN
# 6580               NaN  Economy Class                   NaN            NaN
#
#       Seat Comfort  Cabin Staff Service  Food & Beverages  Ground Service  \
# 1263           5.0                  5.0               5.0             5.0
# 5429           4.0                  4.0               3.0             NaN
# 6580           4.0                  1.0               0.0             NaN
#
#       Inflight Entertainment  Wifi & Connectivity
# 1263                     NaN                  NaN
# 5429                     2.0                  NaN
# 6580                     0.0                  NaN

# %%
df[df['Wifi & Connectivity'].notnull()].sample(3)
# Out:
#             Airline Name Overall_Rating                   Review_Title  \
# 162   CSA Czech Airlines              9  "Staff was nice and friendly"
# 4446          Air Astana              1             "Food was perfect"
# 7312    Vietnam Airlines              4     "stop raising their voice"
#
#             Review Date                                             Review  \
# 162   10th January 2020   Prague to Copenhagen. Flight was operated by ...
# 4446      17th May 2019    St-Petersburg to Istanbul via Almaty.  A21 n...
# 7312  21st January 2021    Cabin Crew attitude is hostile and disrespec...
#
#              Aircraft Type Of Traveller      Seat Type  \
# 162              A319      Solo Leisure  Economy Class
# 4446  A321neo / A320.      Solo Leisure  Economy Class
# 7312       Boeing 787          Business  Economy Class
#
#                                      Route    Date Flown  Seat Comfort  \
# 162                   Prague to Copenhagen  October 2019           5.0
# 4446  St-Petersburg to Istanbul via Almaty    April 2019           5.0
# 7312                 Tân sơn Nhat to Hanoi  January 2021           2.0
#
#       Cabin Staff Service  Food & Beverages  Ground Service  \
# 162                   5.0               4.0             5.0
# 4446                  5.0               5.0             5.0
# 7312                  1.0               3.0             3.0
#
#       Inflight Entertainment  Wifi & Connectivity
# 162                      2.0                  1.0
# 4446                     4.0                  4.0
# 7312                     4.0                  3.0

# %%
df.describe()
# Out:
#        Seat Comfort  Cabin Staff Service  Food & Beverages  Ground Service  \
# count  15456.000000         15366.000000      11924.000000    15056.000000
# mean       2.598344             2.850709          2.536313        2.330433
# std        1.456198             1.595379          1.513762        1.591097
# min        0.000000             0.000000          0.000000        1.000000
# 25%        1.000000             1.000000          1.000000        1.000000
# 50%        3.000000             3.000000          2.000000        1.000000
# 75%        4.000000             4.000000          4.000000        4.000000
# max        5.000000             5.000000          5.000000        5.000000
#
#        Inflight Entertainment  Wifi & Connectivity
# count             9231.000000          5243.000000
# mean                 2.244611             1.800877
# std                  1.486511             1.327095
# min                  0.000000             0.000000
# 25%                  1.000000             1.000000
# 50%                  2.000000             1.000000
# 75%                  3.000000             2.000000
# max                  5.000000             5.000000

# %%
df.describe(include='object')
# Out:
#        Airline Name Overall_Rating              Review_Title     Review Date  \
# count         17673          17673                     17673           17673
# unique          182             10                     14268            3679
# top         CityJet              1  Onur Air customer review  16th July 2023
# freq            100           9370                        84              64
#
#                                                    Review Aircraft  \
# count                                               17673     5665
# unique                                              17670      835
# top       Very attentive staff at airport check in and...     A320
# freq                                                    2      768
#
#        Type Of Traveller      Seat Type                Route Date Flown
# count              15953          17461                15876      15944
# unique                 4              4                11294        108
# top         Solo Leisure  Economy Class  Melbourne to Sydney  June 2023
# freq                5780          14987                   38        998

# %%
df[df.duplicated(subset=['Review'], keep=False)][['Airline Name', 'Review_Title', 'Overall_Rating','Review', 'Review Date', 'Type Of Traveller', 'Route', 'Aircraft','Date Flown']]
# Out:
#                   Airline Name                              Review_Title  \
# 9167   China Southern Airlines         "Very attentive staff at airport"
# 10168                 Tunisair                  Tunisair customer review
# 13004          Alaska Airlines              "Not a great airline at all"
# 13005          Alaska Airlines  "flight attendants did the bare minimum"
# 13448  China Southern Airlines          "happily fly this airline again"
# 17161                 Tunisair                  Tunisair customer review
#
#       Overall_Rating                                             Review  \
# 9167               1    Very attentive staff at airport check in and...
# 10168              2  LHR-TUN return to LHR. Aircraft was A320 on bo...
# 13004              1    Terrible attitude from the lady at 11am at g...
# 13005              1    Terrible attitude from the lady at 11am at g...
# 13448              8    Very attentive staff at airport check in and...
# 17161              9  LHR-TUN return to LHR. Aircraft was A320 on bo...
#
#               Review Date Type Of Traveller                    Route  \
# 9167      24th March 2022      Solo Leisure    Guangzhou to Auckland
# 10168      26th July 2012               NaN                      NaN
# 13004   30th January 2023    Family Leisure  San Francisco to Newark
# 13005   30th January 2023    Family Leisure  San Francisco to Newark
# 13448  31st December 2022      Solo Leisure       Guangzhou to Paris
# 17161      9th April 2012               NaN                      NaN
#
#              Aircraft     Date Flown
# 9167              NaN     March 2022
# 10168             NaN            NaN
# 13004  Boeing 737-900   January 2023
# 13005  Boeing 737-900   January 2023
# 13448             NaN  December 2022
# 17161             NaN            NaN

# %%
df.columns
# Out:
# Index(['Airline Name', 'Overall_Rating', 'Review_Title', 'Review Date',
#        'Review', 'Aircraft', 'Type Of Traveller', 'Seat Type', 'Route',
#        'Date Flown', 'Seat Comfort', 'Cabin Staff Service', 'Food & Beverages',
#        'Ground Service', 'Inflight Entertainment', 'Wifi & Connectivity'],
#       dtype='object')

# %%
df.drop_duplicates(subset=['Airline Name', 'Review', 'Overall_Rating', 'Date Flown', 'Route', 'Aircraft'], keep='last', inplace=True)
df.describe(include='object')
# Out:
#        Airline Name Overall_Rating              Review_Title     Review Date  \
# count         17672          17672                     17672           17672
# unique          182             10                     14267            3679
# top         CityJet              1  Onur Air customer review  16th July 2023
# freq            100           9369                        84              64
#
#                                                    Review Aircraft  \
# count                                               17672     5664
# unique                                              17670      835
# top       Very attentive staff at airport check in and...     A320
# freq                                                    2      768
#
#        Type Of Traveller      Seat Type                Route Date Flown
# count              15952          17460                15875      15943
# unique                 4              4                11294        108
# top         Solo Leisure  Economy Class  Melbourne to Sydney  June 2023
# freq                5780          14986                   38        998

# %%
df.Overall_Rating.value_counts(normalize=True).round(2) * 100
# Out:
# Overall_Rating
# 1    53.0
# 2    11.0
# 9     7.0
# 8     7.0
# 3     6.0
# 7     5.0
# 4     3.0
# 5     3.0
# 6     3.0
# n     2.0
# Name: proportion, dtype: float64

# %%
df[df.Overall_Rating == 'n'].head(3)
# Out:
#               Airline Name Overall_Rating  \
# 74   Aerolineas Argentinas              n
# 389       Regional Express              n
# 394             US Airways              n
#
#                               Review_Title         Review Date  \
# 74   Aerolineas Argentinas customer review  10th December 2014
# 389       Regional Express customer review       10th May 2005
# 394             US Airways customer review       10th May 2015
#
#                                                 Review Aircraft  \
# 74   EZE-JFK. The flight was supposed to leave at 1...      NaN
# 389  Flew REX from Sydney to Lismore January 2005. ...      NaN
# 394  My wife and I decided to travel to Anguilla fo...      NaN
#
#     Type Of Traveller      Seat Type Route Date Flown  Seat Comfort  \
# 74                NaN  Economy Class   NaN        NaN           1.0
# 389               NaN            NaN   NaN        NaN           NaN
# 394               NaN  Economy Class   NaN        NaN           2.0
#
#      Cabin Staff Service  Food & Beverages  Ground Service  \
# 74                   1.0               2.0             NaN
# 389                  NaN               NaN             NaN
# 394                  1.0               1.0             NaN
#
#      Inflight Entertainment  Wifi & Connectivity
# 74                      4.0                  NaN
# 389                     NaN                  NaN
# 394                     0.0                  NaN

# %%
df.drop(df[df.Overall_Rating == 'n'].index, inplace=True)
df.shape
# Out:
# (17367, 16)

# %%
df['Review Date'] = pd.to_datetime(df['Review Date'], errors='coerce')
df['Date Flown'] = pd.to_datetime(df['Date Flown'], errors='coerce')

df['Overall_Rating'] = pd.to_numeric(df['Overall_Rating'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17367 entries, 0 to 17701
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Airline Name            17367 non-null  object
#  1   Overall_Rating          17367 non-null  int64
#  2   Review_Title            17367 non-null  object
#  3   Review Date             13557 non-null  datetime64[ns]
#  4   Review                  17367 non-null  object
#  5   Aircraft                5664 non-null   object
#  6   Type Of Traveller       15952 non-null  object
#  7   Seat Type               17249 non-null  object
#  8   Route                   15875 non-null  object
#  9   Date Flown              15943 non-null  datetime64[ns]
#  10  Seat Comfort            15315 non-null  float64
#  11  Cabin Staff Service     15225 non-null  float64
#  12  Food & Beverages        11783 non-null  float64
#  13  Ground Service          15055 non-null  float64
#  14  Inflight Entertainment  9091 non-null   float64
#  15  Wifi & Connectivity     5242 non-null   float64
# dtypes: datetime64[ns](2), float64(6), int64(1), object(7)
# memory usage: 2.3+ MB

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('&', 'e').str.replace(r'[^\w]', '', regex=True)
df.columns
# Out:
# Index(['airline_name', 'overall_rating', 'review_title', 'review_date',
#        'review', 'aircraft', 'type_of_traveller', 'seat_type', 'route',
#        'date_flown', 'seat_comfort', 'cabin_staff_service', 'food_e_beverages',
#        'ground_service', 'inflight_entertainment', 'wifi_e_connectivity'],
#       dtype='object')

# %% [markdown]
# ## 2- Processamento Texto

# %% [markdown]
# * Limpeza dos campos review e review_title
#
#     * Conversão para minúscula
#     * Remoção de pontuação e números
#     * Remoção de stop-words e lematização

# %%
# Aplicação da função de pré-processamento nos textos das colunas 'review' e 'review_title'
df["review_clean"] = df["review"].apply(preprocess_text_spacy)
df["review_title_clean"] = df["review_title"].apply(preprocess_text_spacy)

df[["review", "review_clean", "review_title", "review_title_clean"]].head()
# Out:
#                                               review  \
# 0  LHR-SEZ-LHR. It's true that there aren't perso...
# 1  London City to Antwerp was delayed 3 hours 40 ...
# 2  PEK to HGH in Economy. Slight delay out of PEK...
# 3  Rio to Buenos Aires AEP on 737. Departure dela...
# 4  Outbound flight FRA/PRN A319. 2 hours 10 min f...
#
#                                         review_clean  \
# 0  lhrsezlhr true not personal tv like virgin ba ...
# 1  london city antwerp delay   hour   min sure tr...
# 2  pek hgh economy slight delay pek uneventful fl...
# 3  rio buenos aire aep   departure delay min arri...
# 4  outbound flight fraprn   hour   min flight thi...
#
#                             review_title  \
# 0         Air Seychelles customer review
# 1                CityJet customer review
# 2      Shanghai Airlines customer review
# 3  Aerolineas Argentinas customer review
# 4          Adria Airways customer review
#
#                       review_title_clean
# 0          air seychelle customer review
# 1                cityjet customer review
# 2      shanghai airlines customer review
# 3  aerolineas argentinas customer review
# 4          adria airways customer review

# %% [markdown]
# ## 3. Feature Engineering

# %% [markdown]
# * Quebra das colunas de data
#     * Dia da semana
#     * Ano-Mês
#     * Ano
#     * Mês
#     * Dias de diferença entre voo e avaliação
# * Quebra da feature overall_rating
#     * Criação de grupos: Negativo(-1), Neutro (0) e Positivo (1)
# * Concatenação de review_title e review
# * Criação de feature que indica atraso no voo

# %%
# Criar coluna com o dia da semana
df['review_day_of_week'] = df['review_date'].dt.day_name()
df['date_flown_day_of_week'] = df['date_flown'].dt.day_name()

# Criar coluna com ano-mês
df['review_year_month'] = df['review_date'].dt.to_period('M')
df['date_flown_year_month'] = df['date_flown'].dt.to_period('M')

# Criar coluna com ano
df['review_year'] = df['review_date'].dt.year
df['date_flown_year'] = df['date_flown'].dt.year

# Criar coluna com mês
df['review_month'] = df['review_date'].dt.month
df['date_flown_month'] = df['date_flown'].dt.month

# Criar coluna com a diferença de dias entre data do voo e data do review
df['days_difference'] = (df['review_date'] - df['date_flown']).dt.days

df[['review_day_of_week', 'date_flown_day_of_week', 'review_year_month', 'date_flown_year_month', 
    'review_year', 'date_flown_year', 'review_month', 'date_flown_month', 'days_difference']].head()
# Out:
#   review_day_of_week date_flown_day_of_week review_year_month  \
# 0             Sunday                    NaN           2011-04
# 1             Sunday                    NaN           2011-04
# 2            Tuesday                    NaN           2012-04
# 3           Thursday                    NaN           2014-04
# 4             Friday                    NaN           2015-04
#
#   date_flown_year_month  review_year  date_flown_year  review_month  \
# 0                   NaT       2011.0              NaN           4.0
# 1                   NaT       2011.0              NaN           4.0
# 2                   NaT       2012.0              NaN           4.0
# 3                   NaT       2014.0              NaN           4.0
# 4                   NaT       2015.0              NaN           4.0
#
#    date_flown_month  days_difference
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN

# %%
df[df.days_difference.notnull()].head(3)
# Out:
#       airline_name  overall_rating                          review_title  \
# 6  Cubana Airlines               2  "wouldn't recommend Cubana Airlines"
# 7          SilkAir               3              "budget airline quality"
# 8       Air Berlin               1     "worst service in business class"
#
#   review_date                                             review aircraft  \
# 6  2016-04-10    Flew from Varadero to Toronto April 8, 2016....     A320
# 7  2016-04-10    Singapore to Kunming with SilkAir. Singapore...      NaN
# 8  2017-04-10    New York JFK to Duesseldorf. The worst servi...      NaN
#
#   type_of_traveller       seat_type                        route date_flown  \
# 6    Family Leisure   Economy Class                   VRA to YYZ 2016-04-01
# 7    Couple Leisure   Economy Class                   SIN to KMG 2015-12-01
# 8    Couple Leisure  Business Class  New York JFK to Duesseldorf 2017-04-01
#
#    seat_comfort  cabin_staff_service  food_e_beverages  ground_service  \
# 6           2.0                  3.0               3.0             2.0
# 7           1.0                  4.0               1.0             5.0
# 8           1.0                  1.0               1.0             1.0
#
#    inflight_entertainment  wifi_e_connectivity  \
# 6                     NaN                  NaN
# 7                     1.0                  NaN
# 8                     1.0                  NaN
#
#                                         review_clean  \
# 6     fly varadero toronto april     flight sched...
# 7     singapore kunme silkair singapore airlines ...
# 8     new york jfk duesseldorf bad service busine...
#
#              review_title_clean review_day_of_week date_flown_day_of_week  \
# 6  not recommend cubana airline             Sunday                 Friday
# 7        budget airline quality             Sunday                Tuesday
# 8    bad service business class             Monday               Saturday
#
#   review_year_month date_flown_year_month  review_year  date_flown_year  \
# 6           2016-04               2016-04       2016.0           2016.0
# 7           2016-04               2015-12       2016.0           2015.0
# 8           2017-04               2017-04       2017.0           2017.0
#
#    review_month  date_flown_month  days_difference
# 6           4.0               4.0              9.0
# 7           4.0              12.0            131.0
# 8           4.0               4.0              9.0

# %%
# Aplicação da função de categorização de rating
df['rating_category'] = df['overall_rating'].apply(categorize_rating)

df[['overall_rating', 'rating_category']].head()
# Out:
#    overall_rating rating_category
# 0               8        Positivo
# 1               1        Negativo
# 2               9        Positivo
# 3               8        Positivo
# 4               7          Neutro

# %%
rating_mapping = {'Negativo': -1, 'Neutro': 0, 'Positivo': 1}
df['rating_category_numeric'] = df['rating_category'].map(rating_mapping)

df[['overall_rating', 'rating_category', 'rating_category_numeric']].head()
# Out:
#    overall_rating rating_category  rating_category_numeric
# 0               8        Positivo                        1
# 1               1        Negativo                       -1
# 2               9        Positivo                        1
# 3               8        Positivo                        1
# 4               7          Neutro                        0

# %%
df['full_review_text'] = df['review_title'].fillna('') + ' ' + df['review'].fillna('')
df.head(3)
# Out:
#         airline_name  overall_rating                       review_title  \
# 0     Air Seychelles               8     Air Seychelles customer review
# 1            CityJet               1            CityJet customer review
# 2  Shanghai Airlines               9  Shanghai Airlines customer review
#
#   review_date                                             review aircraft  \
# 0  2011-04-10  LHR-SEZ-LHR. It's true that there aren't perso...      NaN
# 1  2011-04-10  London City to Antwerp was delayed 3 hours 40 ...      NaN
# 2  2012-04-10  PEK to HGH in Economy. Slight delay out of PEK...      NaN
#
#   type_of_traveller      seat_type route date_flown  seat_comfort  \
# 0               NaN  Economy Class   NaN        NaT           NaN
# 1               NaN  Economy Class   NaN        NaT           NaN
# 2               NaN  Economy Class   NaN        NaT           3.0
#
#    cabin_staff_service  food_e_beverages  ground_service  \
# 0                  NaN               NaN             NaN
# 1                  NaN               NaN             NaN
# 2                  4.0               4.0             NaN
#
#    inflight_entertainment  wifi_e_connectivity  \
# 0                     NaN                  NaN
# 1                     NaN                  NaN
# 2                     2.0                  NaN
#
#                                         review_clean  \
# 0  lhrsezlhr true not personal tv like virgin ba ...
# 1  london city antwerp delay   hour   min sure tr...
# 2  pek hgh economy slight delay pek uneventful fl...
#
#                   review_title_clean review_day_of_week  \
# 0      air seychelle customer review             Sunday
# 1            cityjet customer review             Sunday
# 2  shanghai airlines customer review            Tuesday
#
#   date_flown_day_of_week review_year_month date_flown_year_month  review_year  \
# 0                    NaN           2011-04                   NaT       2011.0
# 1                    NaN           2011-04                   NaT       2011.0
# 2                    NaN           2012-04                   NaT       2012.0
#
#    date_flown_year  review_month  date_flown_month  days_difference  \
# 0              NaN           4.0               NaN              NaN
# 1              NaN           4.0               NaN              NaN
# 2              NaN           4.0               NaN              NaN
#
#   rating_category  rating_category_numeric  \
# 0        Positivo                        1
# 1        Negativo                       -1
# 2        Positivo                        1
#
#                                     full_review_text
# 0  Air Seychelles customer review LHR-SEZ-LHR. It...
# 1  CityJet customer review London City to Antwerp...
# 2  Shanghai Airlines customer review PEK to HGH i...

# %%
delay_keywords = [
    r"\bdelay(ed|s)?\b",          # delay, delayed, delays
    r"\blate\b",                  # late
    r"\blateness\b",              # lateness
    r"\blong wait\b",             # long wait
    r"\bwaiting time\b",          # waiting time
    r"\bwait(ed|ing)?\b",         # wait, waited, waiting
    r"\bpostpone(d)?\b",          # postpone, postponed
    r"\breschedul(ed|ing|e)?\b",  # reschedule, rescheduled
    r"\bflight cancel(l)?ed\b"    # canceled or cancelled (US/UK spelling)
]

# %%
pattern = re.compile('|'.join(delay_keywords), flags=re.IGNORECASE)

df['is_delay'] = df['full_review_text'].apply(lambda x: 1 if pattern.search(x) else 0)

df.head(3)
# Out:
#         airline_name  overall_rating                       review_title  \
# 0     Air Seychelles               8     Air Seychelles customer review
# 1            CityJet               1            CityJet customer review
# 2  Shanghai Airlines               9  Shanghai Airlines customer review
#
#   review_date                                             review aircraft  \
# 0  2011-04-10  LHR-SEZ-LHR. It's true that there aren't perso...      NaN
# 1  2011-04-10  London City to Antwerp was delayed 3 hours 40 ...      NaN
# 2  2012-04-10  PEK to HGH in Economy. Slight delay out of PEK...      NaN
#
#   type_of_traveller      seat_type route date_flown  seat_comfort  \
# 0               NaN  Economy Class   NaN        NaT           NaN
# 1               NaN  Economy Class   NaN        NaT           NaN
# 2               NaN  Economy Class   NaN        NaT           3.0
#
#    cabin_staff_service  food_e_beverages  ground_service  \
# 0                  NaN               NaN             NaN
# 1                  NaN               NaN             NaN
# 2                  4.0               4.0             NaN
#
#    inflight_entertainment  wifi_e_connectivity  \
# 0                     NaN                  NaN
# 1                     NaN                  NaN
# 2                     2.0                  NaN
#
#                                         review_clean  \
# 0  lhrsezlhr true not personal tv like virgin ba ...
# 1  london city antwerp delay   hour   min sure tr...
# 2  pek hgh economy slight delay pek uneventful fl...
#
#                   review_title_clean review_day_of_week  \
# 0      air seychelle customer review             Sunday
# 1            cityjet customer review             Sunday
# 2  shanghai airlines customer review            Tuesday
#
#   date_flown_day_of_week review_year_month date_flown_year_month  review_year  \
# 0                    NaN           2011-04                   NaT       2011.0
# 1                    NaN           2011-04                   NaT       2011.0
# 2                    NaN           2012-04                   NaT       2012.0
#
#    date_flown_year  review_month  date_flown_month  days_difference  \
# 0              NaN           4.0               NaN              NaN
# 1              NaN           4.0               NaN              NaN
# 2              NaN           4.0               NaN              NaN
#
#   rating_category  rating_category_numeric  \
# 0        Positivo                        1
# 1        Negativo                       -1
# 2        Positivo                        1
#
#                                     full_review_text  is_delay
# 0  Air Seychelles customer review LHR-SEZ-LHR. It...         0
# 1  CityJet customer review London City to Antwerp...         1
# 2  Shanghai Airlines customer review PEK to HGH i...         1

# %%
len(df[df['is_delay'] == 1]) / len(df) * 100
# Out:
# 40.28905395289918

# %%
df.to_parquet('../data/processed/abt_airline_reviews.parquet', index=False)
